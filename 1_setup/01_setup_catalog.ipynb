# %%
# %sql

-- Creating FMCG Catalog 
CREATE CATALOG IF NOT EXISTS fmcg;

USE CATALOG fmcg;

# %%
# %sql

--- Gold layer contains consolidated data of Parent(Velocity Gear) and Child(Vitality Nutrition) company data 
CREATE SCHEMA IF NOT EXISTS fmcg.gold;

# %%
# %sql

--- Creating Bronze and Silver layers for Child Company  
CREATE SCHEMA IF NOT EXISTS fmcg.silver;
CREATE SCHEMA IF NOT EXISTS fmcg.bronze;
